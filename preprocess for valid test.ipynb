# %%
import numpy as np
import pandas as pd
te=pd.read_csv("test_processed.csv")
va=pd.read_csv("valid_processed.csv")

# %%
va
# Out:
#                                           reviewComment  usefulCount  \
# 0     "Getting it taken out after 6 months of non-st...            3
# 1     "Had 1st shot of Simponi and didn&#039;t notic...            3
# 2     "Awesome. Best medicine I&#039;ve ever found f...          406
# 3     "Can&#039;t recommend more highly.  Unless my ...           39
# 4     "I need to lose 30 lbs. I tried every thing, e...           58
# ...                                                 ...          ...
# 1194  "Did not work well in the spots where I rubbed...           81
# 1195  "I took Concerta when I was in high school for...           16
# 1196  "I quit abusing medicines and drinking 2 1/2 y...           15
# 1197  "I developed Irritable Bowel Syndrome-C and ch...           73
# 1198  "The doctor used propofol for a colonoscopy.  ...           30
#
#                         sideEffects  condition_target_encoded  \
# 0                 Mild Side Effects                  3.287747
# ...

# %%
# sensitive
from textblob import TextBlob

for i in range(0, len(va)):
    txt=TextBlob(va['reviewComment'][i])
    va['reviewComment'][i]=txt.sentiment
    
for i in range(0, len(va)):
    if va['reviewComment'][i][1]>0:
        va['reviewComment'][i]=1
    else:
        va['reviewComment'][i]=-1
# Out:
# <ipython-input-18-1ba545db6470>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['reviewComment'][i]=txt.sentiment
# <ipython-input-18-1ba545db6470>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['reviewComment'][i]=-1
# <ipython-input-18-1ba545db6470>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['reviewComment'][i]=1

# %%
# sensitive
from textblob import TextBlob

for i in range(0, len(te)):
    txt=TextBlob(te['reviewComment'][i])
    te['reviewComment'][i]=txt.sentiment
    
for i in range(0, len(te)):
    if te['reviewComment'][i][1]>0:
        te['reviewComment'][i]=1
    else:
        te['reviewComment'][i]=-1
# Out:
# <ipython-input-19-f7f9958c4b3a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['reviewComment'][i]=txt.sentiment
# <ipython-input-19-f7f9958c4b3a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['reviewComment'][i]=1
# <ipython-input-19-f7f9958c4b3a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['reviewComment'][i]=-1

# %%
## sideEffect
import matplotlib.pyplot as plt

# %%
#No Side Effects:5;Mild Side Effects:4;Moderate Side Effects:3;Severe Side Effects:2;Extremely Severe Side Effects:1
# 将sideEffect数字化
for i in range (0, len(va)):
    if va['sideEffects'][i]=='No Side Effects':
        va['sideEffects'][i]=5
    elif va['sideEffects'][i]=='Mild Side Effects':
        va['sideEffects'][i]=4
    elif va['sideEffects'][i]=='Moderate Side Effects':
        va['sideEffects'][i]=3
    elif va['sideEffects'][i]=='Severe Side Effects':
        va['sideEffects'][i]=2
    else:
        va['sideEffects'][i]=1
# Out:
# <ipython-input-21-27dc33b56f52>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['sideEffects'][i]=4
# <ipython-input-21-27dc33b56f52>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['sideEffects'][i]=2
# <ipython-input-21-27dc33b56f52>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['sideEffects'][i]=3
# <ipython-input-21-27dc33b56f52>:5: SettingWithCopyWarning:
# ...

# %%
#No Side Effects:5;Mild Side Effects:4;Moderate Side Effects:3;Severe Side Effects:2;Extremely Severe Side Effects:1
# 将sideEffect数字化
for i in range (0, len(te)):
    if te['sideEffects'][i]=='No Side Effects':
        te['sideEffects'][i]=5
    elif te['sideEffects'][i]=='Mild Side Effects':
        te['sideEffects'][i]=4
    elif te['sideEffects'][i]=='Moderate Side Effects':
        te['sideEffects'][i]=3
    elif te['sideEffects'][i]=='Severe Side Effects':
        te['sideEffects'][i]=2
    else:
        te['sideEffects'][i]=1
# Out:
# <ipython-input-7-d69c3865d5a6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['sideEffects'][i]=2
# <ipython-input-7-d69c3865d5a6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['sideEffects'][i]=3
# <ipython-input-7-d69c3865d5a6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['sideEffects'][i]=4
# <ipython-input-7-d69c3865d5a6>:5: SettingWithCopyWarning:
# ...

# %%
va
# Out:
#      reviewComment  usefulCount sideEffects  condition_target_encoded  \
# 0        -5.525138    -0.673852    0.262847                 -0.071260
# 1          0.18084    -0.673852   -1.436092                 -2.819041
# 2          0.18084     9.402070    0.262847                  0.347859
# 3          0.18084     0.226230   -0.586623                  0.369244
# 4          0.18084     0.701274    1.112316                  0.799542
# ...            ...          ...         ...                       ...
# 1194       0.18084     1.276326    1.112316                 -2.819041
# 1195       0.18084    -0.348823    0.262847                  0.220101
# 1196       0.18084    -0.373825   -2.285562                  0.492277
# 1197       0.18084     1.076308    0.262847                 -0.311749
# 1198       0.18084     0.001209    1.112316                  0.133992
#
#       year_target_encoded     month       day  rating
# 0                0.638608  1.622311 -0.099232       1
# ...

# %%
te
# Out:
#      reviewComment  usefulCount sideEffects  condition_target_encoded  \
# 0                1            1           2                  3.287747
# 1                1            0           3                  0.000000
# 2                1           13           4                  2.309735
# 3                1            7           4                  3.962025
# 4                1           11           3                  3.444444
# ...            ...          ...         ...                       ...
# 1793             1          176           3                  5.000000
# 1794             1            8           2                  2.000000
# 1795             1            2           1                  2.309735
# 1796             1           58           4                  4.140741
# 1797             1           17           3                  3.777778
#
#       year_target_encoded  month  day  rating
# 0                3.231955      9   10     NaN
# ...

# %%
#standard for every attributes of valid
X=va['sideEffects']
X=(X-X.mean())/X.std()
va['sideEffects']=X

X=va['reviewComment']
X=(X-X.mean())/X.std()
va['reviewComment']=X

X=va['usefulCount']
X=(X-X.mean())/X.std()
va['usefulCount']=X

X=va['condition_target_encoded']
X=(X-X.mean())/X.std()
va['condition_target_encoded']=X

X=va['year_target_encoded']
X=(X-X.mean())/X.std()
va['year_target_encoded']=X

X=va['month']
X=(X-X.mean())/X.std()
va['month']=X

X=va['day']
X=(X-X.mean())/X.std()
va['day']=X

# %%
X=te['sideEffects']
X=(X-X.mean())/X.std()
te['sideEffects']=X

X=te['reviewComment']
X=(X-X.mean())/X.std()
te['reviewComment']=X

X=te['usefulCount']
X=(X-X.mean())/X.std()
te['usefulCount']=X

X=te['condition_target_encoded']
X=(X-X.mean())/X.std()
te['condition_target_encoded']=X

X=te['year_target_encoded']
X=(X-X.mean())/X.std()
te['year_target_encoded']=X

X=te['month']
X=(X-X.mean())/X.std()
te['month']=X

X=te['day']
X=(X-X.mean())/X.std()
te['day']=X

# %%
va.to_csv("valid_processed2.csv",index=False)

# %%
te.to_csv("test_processed2.csv",index=False)
