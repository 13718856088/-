# %%
import numpy as np
import pandas as pd
tr=pd.read_csv("training.csv")
te=pd.read_csv("testing.csv")
va=pd.read_csv("validation.csv")

# %%
## Classify drugNames in conditions
condition_drug = tr.groupby(['condition'])['drugName'].nunique().sort_values(ascending=False)
condition_drug
# Out:
# condition
# Birth Control                      104
# Pain                                80
# Depression                          68
# Acne                                51
# Anxiety                             44
#                                   ...
# Diaper Rash                          1
# Pancreatic Exocrine Dysfunction      1
# Diagnosis and Investigation          1
# Paranoid Disorde                     1
# moterol)                             1
# Name: drugName, Length: 408, dtype: int64

# %%
# Visualize the top 15 most numerous conditions
import matplotlib.pyplot as plt
condition_drug[0:15].plot(kind="bar", figsize = (10,6), fontsize = 10,color="orange")
plt.xlabel("", fontsize = 10)
plt.ylabel("", fontsize = 10)
plt.title(" Top 15 :The number of drugs per condition.", fontsize = 10)
# Out:
# Text(0.5, 1.0, ' Top 15 :The number of drugs per condition.')

# %%
# The last 15 species are on display
condition_drug[condition_drug.shape[0]-15:condition_drug.shape[0]].plot(kind="bar", figsize = (10,6), fontsize = 10,color="green")
plt.xlabel("", fontsize = 10)
plt.ylabel("", fontsize = 10)
plt.title(" Bottom 15:The number of drugs per condition.", fontsize = 10)
# Out:
# Text(0.5, 1.0, ' Bottom 15:The number of drugs per condition.')

# %%
# View the condition overview in testing
condition_drug_te = te.groupby(['condition'])['drugName'].nunique().sort_values(ascending=False)
condition_drug_te
# Out:
# condition
# Birth Control               67
# Pain                        38
# Depression                  37
# Acne                        29
# Anxiety                     26
#                             ..
# Herbal Supplementation       1
# Herpes Simplex               1
# Herpes Zoste                 1
# Hiccups                      1
# von Willebrand's Disease     1
# Name: drugName, Length: 249, dtype: int64

# %%
# Zero gibberish content
List=['0</span> users found this comment helpful.','1</span> users found this comment helpful.','2</span> users found this comment helpful.','3</span> users found this comment helpful.','4</span> users found this comment helpful.','5</span> users found this comment helpful.','6</span> users found this comment helpful.','7</span> users found this comment helpful.','8</span> users found this comment helpful.','9</span> users found this comment helpful.','10</span> users found this comment helpful.',
      '11</span> users found this comment helpful.','12</span> users found this comment helpful.','13</span> users found this comment helpful.','14</span> users found this comment helpful.','15</span> users found this comment helpful.','16</span> users found this comment helpful.','17</span> users found this comment helpful.','18</span> users found this comment helpful.','19</span> users found this comment helpful.','20</span> users found this comment helpful.',
      '21</span> users found this comment helpful.','22</span> users found this comment helpful.','23</span> users found this comment helpful.','24</span> users found this comment helpful.','25</span> users found this comment helpful.','31</span> users found this comment helpful.','33</span> users found this comment helpful.','38</span> users found this comment helpful.','39</span> users found this comment helpful.']
for i in range(0,len(tr)):
    for j in range(0,len(List)):
        if tr['condition'][i]==List[j]:
            tr['condition'][i]='None'
for i in range(0,len(te)):
    for j in range(0,len(List)):
        if te['condition'][i]==List[j]:
            te['condition'][i]='None'
for i in range(0,len(va)):
    for j in range(0,len(List)):
        if va['condition'][i]==List[j]:
            va['condition'][i]='None'
# Out:
# <ipython-input-112-ffc0e6ebe6c3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['condition'][i]='None'
# <ipython-input-112-ffc0e6ebe6c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['condition'][i]='None'
# <ipython-input-112-ffc0e6ebe6c3>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['condition'][i]='None'

# %%
tr[tr['condition']=='None']
# Out:
#       recordId               drugName condition  \
# 136      33560  Microgestin Fe 1 / 20      None
# 211     133232           Tri-Sprintec      None
# 348      60892          Kombiglyze XR      None
# 368      66762               Seroquel      None
# 572     156099                 Cialis      None
# 719     133358           Tri-Sprintec      None
# 778      98290              Nexplanon      None
# 1052    221271                 Drysol      None
# 1153    230621           Depo-Provera      None
# 1214    119172                 Zoloft      None
# 1291     42886                 Xulane      None
# 1533    219226           Ortho Cyclen      None
# 2011    161409       Ortho Tri-Cyclen      None
# 2133     29968               Klonopin      None
# 2332     71394                 Levora      None
# 2656    219512                Pataday      None
# 2788    221031      Junel Fe 1.5 / 30      None
# 2853    169450                Vivarin      None
# ...

# %%
## reviewComment
# wordCloud
from wordcloud import WordCloud, STOPWORDS

text = str(tr['reviewComment'])

stopwords = set(STOPWORDS)
more_stopwords = {'ve', 'th', 'al', 't', 'wi', 's', 'wit', 'mg', 'e'}
stopwords = stopwords.union(more_stopwords)

wcloud = WordCloud(width=2800, height=1600, stopwords=stopwords, max_words=500).generate(text)

plt.imshow(wcloud)
plt.axis('off')
plt.show()

# %%
import datetime

# %%
## date
from datetime import datetime

i = 0
GMT_FORMAT = '%d-%b-%y'

tr['year'] = ''
tr['month'] = ''
tr['day'] = ''

for i in range(len(tr)):
    if '-' in tr['date'][i]:
        dt = datetime.strptime(tr['date'][i], GMT_FORMAT)
        tr['year'][i] = dt.year
        tr['month'][i] = dt.month
        tr['day'][i] = dt.day
    else:
        tr['year'][i] = None
        tr['month'][i] = None
        tr['day'][i] = None
# Out:
# <ipython-input-118-7f7fba55e8c8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['year'][i] = dt.year
# <ipython-input-118-7f7fba55e8c8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['month'][i] = dt.month
# <ipython-input-118-7f7fba55e8c8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['day'][i] = dt.day

# %%
# 展示年份的平均rating
rating = tr.groupby('year')['rating'].mean()
rating.plot(kind="bar", figsize = (10,6), fontsize = 10,color="green")

plt.xlabel("", fontsize = 15)
plt.ylabel("", fontsize = 15)
plt.title("Mean rating in year", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Mean rating in year')

# %%
# 展示月份的平均rating
rating = tr.groupby('month')['rating'].mean()
rating.plot(kind="bar", figsize = (10,6), fontsize = 10,color="red")

plt.xlabel("", fontsize = 15)
plt.ylabel("", fontsize = 15)
plt.title("Mean rating in month", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Mean rating in month')

# %%
# 展示单日的平均rating
rating = tr.groupby('day')['rating'].mean()
rating.plot(kind="bar", figsize = (10,6), fontsize = 10,color="blue")

plt.xlabel("", fontsize = 15)
plt.ylabel("", fontsize = 15)
plt.title("Mean rating in day", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Mean rating in day')

# %%
#seperate date for test and valid
i = 0
GMT_FORMAT = '%d-%b-%y'

va['year'] = ''
va['month'] = ''
va['day'] = ''

for i in range(len(va)):
    if '-' in va['date'][i]:
        dt = datetime.strptime(va['date'][i], GMT_FORMAT)
        va['year'][i] = dt.year
        va['month'][i] = dt.month
        va['day'][i] = dt.day
    else:
        va['year'][i] = None
        va['month'][i] = None
        va['day'][i] = None
# Out:
# <ipython-input-113-c48efcbcecbf>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['year'][i] = dt.year
# <ipython-input-113-c48efcbcecbf>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['month'][i] = dt.month
# <ipython-input-113-c48efcbcecbf>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va['day'][i] = dt.day

# %%
i = 0
GMT_FORMAT = '%d-%b-%y'

te['year'] = ''
te['month'] = ''
te['day'] = ''

for i in range(len(te)):
    if '-' in te['date'][i]:
        dt = datetime.strptime(te['date'][i], GMT_FORMAT)
        te['year'][i] = dt.year
        te['month'][i] = dt.month
        te['day'][i] = dt.day
    else:
        te['year'][i] = None
        te['month'][i] = None
        te['day'][i] = None
# Out:
# <ipython-input-114-4da844c6950c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['year'][i] = dt.year
# <ipython-input-114-4da844c6950c>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['month'][i] = dt.month
# <ipython-input-114-4da844c6950c>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['day'][i] = dt.day

# %%
#target encoding definition
def target_encode(X, X_valid, categorical_features, X_test=None,
                  target_feature='target'):
    print('Target Encoding: {}'.format(categorical_features))
    X_ = pd.DataFrame()
    X_valid_ = pd.DataFrame()
    if X_test is not None:
        X_test_ = pd.DataFrame()
    for cat_feature in categorical_features:
        group_target_mean = X.groupby([cat_feature])[target_feature].mean()
        X_[cat_feature] = X[cat_feature].map(group_target_mean)
        X_valid_[cat_feature] = X_valid[cat_feature].map(group_target_mean)
    X_ = X_.astype(np.float32)
    X_ = X_.add_suffix('_target_encoded')
    X_valid_ = X_valid_.astype(np.float32)
    X_valid_ = X_valid_.add_suffix('_target_encoded')
    if X_test is not None:
        X_test_[cat_feature] = X_test[cat_feature].map(group_target_mean)
        X_test_ = X_test_.astype(np.float32)
        X_test_ = X_test_.add_suffix('_target_encoded')
        return X_, X_valid_, X_test_
    return X_, X_valid

# %%
# target encoding for condition
tr_condition, va_condition,te_condition = target_encode(
    tr, va, categorical_features=['condition'],X_test=te,
    target_feature='rating')
# Out:
# Target Encoding: ['condition']

# %%
# target encoding for year
tr_year, va_year,te_year = target_encode(
    tr, va, categorical_features=['year'],X_test=te,
    target_feature='rating')
# Out:
# Target Encoding: ['year']

# %%
# get encoding of condition value for testing and validation
encoded=tr_condition.condition_target_encoded.value_counts().index.values
raw = tr.condition.value_counts().index.values
encoding_dict = dict(zip(raw, encoded))

tr['condition_target_encoded'] = tr.loc[:,
                                                                 'condition'].map(
                                                                 encoding_dict)
 
te['condition_target_encoded'] = te.loc[:,
                                                                 'condition'].map(
                                                                 encoding_dict)
va['condition_target_encoded'] = va.loc[:,
                                                                 'condition'].map(
                                                                 encoding_dict)

# %%
# get encoding of year value for testing and validation
encoded=tr_year.year_target_encoded.value_counts().index.values
raw = tr.year.value_counts().index.values
encoding_dict = dict(zip(raw, encoded))

tr['year_target_encoded'] = tr.loc[:,
                                                                 'year'].map(
                                                                 encoding_dict)
 
te['year_target_encoded'] = te.loc[:,
                                                                 'year'].map(
                                                                 encoding_dict)
va['year_target_encoded'] = va.loc[:,
                                                                 'year'].map(
                                                                 encoding_dict)

# %%
tr
# Out:
#       recordId               drugName                       condition  \
# 0       163740            Mirtazapine                      Depression
# 1       206473             Mesalamine    Crohn's Disease, Maintenance
# 2       159672                Bactrim         Urinary Tract Infection
# 3        39293               Contrave                     Weight Loss
# 4        97768        Cyclafem 1 / 35                   Birth Control
# ...        ...                    ...                             ...
# 6994     21322           Rivastigmine             Alzheimer's Disease
# 6995    172273             Clonazepam  Periodic Limb Movement Disorde
# 6996     29177             Topiramate                         Obesity
# 6997    197612  Suprep Bowel Prep Kit               Bowel Preparation
# 6998     24340             Telaprevir                     Hepatitis C
#
#                                           reviewComment       date  \
# ...

# %%
# sensitive deal for train
from textblob import TextBlob

for i in range(0, len(tr)):
    txt=TextBlob(tr['reviewComment'][i])
    tr['reviewComment'][i]=txt.sentiment
    
for i in range(0, len(tr)):
    if tr['reviewComment'][i][1]>0:
        tr['reviewComment'][i]=1
    else:
        tr['reviewComment'][i]=-1
# Out:
# <ipython-input-77-33bc65e4bd84>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['reviewComment'][i]=txt.sentiment
# <ipython-input-77-33bc65e4bd84>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['reviewComment'][i]=1
# <ipython-input-77-33bc65e4bd84>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['reviewComment'][i]=-1

# %%
tr.loc[:, ('reviewComment')]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6994    1
# 6995    1
# 6996    1
# 6997    1
# 6998    1
# Name: reviewComment, Length: 6999, dtype: object

# %%
tr
# Out:
#       recordId               drugName                       condition  \
# 0       163740            Mirtazapine                      Depression
# 1       206473             Mesalamine    Crohn's Disease, Maintenance
# 2       159672                Bactrim         Urinary Tract Infection
# 3        39293               Contrave                     Weight Loss
# 4        97768        Cyclafem 1 / 35                   Birth Control
# ...        ...                    ...                             ...
# 6994     21322           Rivastigmine             Alzheimer's Disease
# 6995    172273             Clonazepam  Periodic Limb Movement Disorde
# 6996     29177             Topiramate                         Obesity
# 6997    197612  Suprep Bowel Prep Kit               Bowel Preparation
# 6998     24340             Telaprevir                     Hepatitis C
#
#      reviewComment       date  usefulCount          sideEffects  rating  year  \
# ...

# %%
## sideEffect
import matplotlib.pyplot as plt

# %%
# View sideEffect classifications and visualize them
sideeffect_drug = tr.groupby(['sideEffects'])['drugName'].nunique().sort_values(ascending=False)

sideeffect_drug.plot(kind="bar", figsize = (10,6), fontsize = 10,color="orange")
plt.xlabel("", fontsize = 6)
plt.ylabel("", fontsize = 6)
plt.title(" The number of drugs about sideEffect.", fontsize = 10)
# Out:
# Text(0.5, 1.0, ' The number of drugs about sideEffect.')

# %%
#No Side Effects:5;Mild Side Effects:4;Moderate Side Effects:3;Severe Side Effects:2;Extremely Severe Side Effects:1
# Digitize sideEffect
for i in range (0, len(tr)):
    if tr['sideEffects'][i]=='No Side Effects':
        tr['sideEffects'][i]=5
    elif tr['sideEffects'][i]=='Mild Side Effects':
        tr['sideEffects'][i]=4
    elif tr['sideEffects'][i]=='Moderate Side Effects':
        tr['sideEffects'][i]=3
    elif tr['sideEffects'][i]=='Severe Side Effects':
        tr['sideEffects'][i]=2
    else:
        tr['sideEffects'][i]=1
# Out:
# <ipython-input-82-0a265623a7f0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['sideEffects'][i]=4
# <ipython-input-82-0a265623a7f0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['sideEffects'][i]=2
# <ipython-input-82-0a265623a7f0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr['sideEffects'][i]=5
# <ipython-input-82-0a265623a7f0>:13: SettingWithCopyWarning:
# ...

# %%
tr['condition_target_encoded'].fillna(0, inplace=True)
te['condition_target_encoded'].fillna(0, inplace=True)
va['condition_target_encoded'].fillna(0, inplace=True)

# %%
tr=tr.drop(['drugName','recordId','condition', 'date','year'],axis=1)
va=va.drop(['drugName','recordId','condition', 'date','year'],axis=1)
te=te.drop(['drugName','recordId','condition', 'date','year'],axis=1)

# %%
order=['reviewComment','usefulCount','sideEffects','condition_target_encoded','year_target_encoded','month','day','rating']

# %%
order2=['reviewComment','usefulCount','sideEffects','condition_target_encoded','year_target_encoded','month','day']

# %%
tr=tr[order]
va=va[order]
te=te[order2]
#now we get processed train data
#In above steps we just mapping target encoding to test and valid ,
#and not do more to these dataset.We will do some process in file2.

# %%
tr
# Out:
#      reviewComment  usefulCount sideEffects  condition_target_encoded  \
# 0         0.179288    -0.154696    0.259565                  0.344034
# 1         0.179288    -0.279672   -1.443855                  0.995118
# 2         0.179288    -0.629604    1.111276                  0.812490
# 3         0.179288     0.170241    0.259565                  0.809336
# 4         0.179288    -0.604609   -1.443855                 -0.087722
# ...            ...          ...         ...                       ...
# 6994      0.179288    -0.429643    0.259565                 -2.918351
# 6995      0.179288    -0.704590    1.111276                 -2.918351
# 6996      0.179288     1.270029    0.259565                  0.333489
# 6997      0.179288    -0.679594    1.111276                 -0.770674
# 6998      0.179288    -0.654599    1.111276                  0.194362
#
#       year_target_encoded     month       day  rating
# 0                0.691818 -1.302975  1.406146       5
# ...

# %%
te
# Out:
#                                           reviewComment  usefulCount  \
# 0     "I was on Microgestin Fe 1/20 for three months...            1
# 1     "Have had clusters for 45 years, remember the ...            0
# 2     "On June 6th 2015 I took plan B 4 HOURS after ...           13
# 3     "I tried Chantix for a period of 2 months.  My...            7
# 4     "I was diagnosed with Sleep Apnea, for that I ...           11
# ...                                                 ...          ...
# 1793  "I was given Ativan for occasional use. I try ...          176
# 1794  "This antibiotic is the best, hands down.  The...            8
# 1795  "I took this pill on June 16th 2015. I was rea...            2
# 1796  "I developed severe pancreatitis and hepatitis...           58
# 1797  "lupron is not for everyone! I must admit I wa...           17
#
#                         sideEffects  condition_target_encoded  \
# 0               Severe Side Effects                  3.287747
# ...

# %%
#standard for every attributes
X=tr['sideEffects']
X=(X-X.mean())/X.std()
tr['sideEffects']=X

X=tr['reviewComment']
X=(X-X.mean())/X.std()
tr['reviewComment']=X

X=tr['usefulCount']
X=(X-X.mean())/X.std()
tr['usefulCount']=X

X=tr['condition_target_encoded']
X=(X-X.mean())/X.std()
tr['condition_target_encoded']=X

X=tr['year_target_encoded']
X=(X-X.mean())/X.std()
tr['year_target_encoded']=X

X=tr['month']
X=(X-X.mean())/X.std()
tr['month']=X

X=tr['day']
X=(X-X.mean())/X.std()
tr['day']=X
#########################
#for standard we compare result using standard data and not standard data,
#we find not standard data get a little better result .the f1-score is in
#our report

# %%
tr.to_csv("train_processed.csv",index=False)

# %%
va.to_csv("valid_processed.csv",index=False)

# %%
te.to_csv("test_processed.csv",index=False)
